# %%
# !cp '/content/drive/MyDrive/Colab Notebooks/word2vec' ./

# %%
# !cp '/content/drive/MyDrive/Colab Notebooks/word2vec.trainables.syn1neg.npy' ./
# !cp '/content/drive/MyDrive/Colab Notebooks/word2vec.trainables.syn1.npy' ./
# !cp '/content/drive/MyDrive/Colab Notebooks/word2vec.wv.vectors.npy' ./

# %%
from gensim.models import word2vec

# %%
m_w2v = word2vec.Word2Vec.load('word2vec')
words = m_w2v.wv.index2word
vecs = m_w2v.wv.vectors

# %%
m_w2v.most_similar(positive='희망')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('꿈', 0.741871178150177),
#  ('행복', 0.726057767868042),
#  ('소망', 0.6994969844818115),
#  ('기쁨', 0.6814701557159424),
#  ('젊음', 0.6756322383880615),
#  ('열정', 0.6606574654579163),
#  ('염원', 0.6494768857955933),
#  ('아픔', 0.6477082967758179),
#  ('행운', 0.6449261903762817),
#  ('즐거움', 0.6447843313217163)]

# %%
m_w2v.most_similar(positive='부모')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('조부모', 0.8106859922409058),
#  ('양부모', 0.764912486076355),
#  ('양친', 0.7450898885726929),
#  ('어머니', 0.7350335121154785),
#  ('아버지', 0.7143515348434448),
#  ('시부모', 0.7134706974029541),
#  ('친부모', 0.7044199705123901),
#  ('외아들', 0.6913831830024719),
#  ('아내', 0.6871759295463562),
#  ('외조부모', 0.6869087219238281)]
