# %%
# cpu 로 학습한다.

# %%
# !git clone https://github.com/facebookresearch/fastText.git
# Out:
# Cloning into 'fastText'...
# remote: Enumerating objects: 3854, done.
# remote: Total 3854 (delta 0), reused 0 (delta 0), pack-reused 3854
# Receiving objects: 100% (3854/3854), 8.22 MiB | 30.96 MiB/s, done.
# Resolving deltas: 100% (2417/2417), done.

# %%
# !cd /content/fastText
# !make
# !pip install .

# %%
# !cp '/content/drive/MyDrive/Colab Notebooks/corpus_mecab.txt.zip' ./

# %%
# !unzip corpus_mecab.txt.zip
# Out:
# Archive:  corpus_mecab.txt.zip
#   inflating: corpus_mecab.txt

# %%
# !/content/fastText/fasttext skipgram -input /content/corpus_mecab.txt -output /content/fasttext_model/fasttext
# Out:
# Read 233M words
# Number of words:  358043
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   12550 lr:  0.000000 avg.loss:  0.474225 ETA:   0h 0m 0s

# %%
# !cp /content/fasttext_model/* '/content/drive/MyDrive/Colab Notebooks/model/'

# %%
from fasttext import load_model as load_ft_model

# %%
from gensim.models import FastText
m_w2v = word2vec.Word2Vec.load('word2vec')

# %%
model = FastText(result, size=100, window=5, min_count=5, workers=4, sg=1)
model.wv.most_similar("electrofishing")
