# %%
# !pip install fasttext
# Out:
# ...
#      |████████████████████████████████| 68 kB 2.7 MB/s
# ...
#   Using cached pybind11-2.7.1-py2.py3-none-any.whl (200 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3094670 sha256=1d39c61c6c7f46db8afbc4a8f925b27de329c27d04394a0b2e382d7b13460a52
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/bf/b020d2be95f7641801a6597a29c8f4f19e38f9c02a345bab9b
# Successfully built fasttext
# ...
# ^C

# %%
cp -r '/content/drive/MyDrive/Colab Notebooks/model/' ./

# %%
from fasttext import load_model as load_ft_model
model = load_ft_model('./model/fasttext.bin')

# %%
model.get_nearest_neighbors("희망")
# Out:
# [(0.7668576240539551, '행복'),
#  (0.7173705101013184, '소망'),
#  (0.6973574161529541, '꿈'),
#  (0.6818251013755798, '희망찬'),
#  (0.6685357093811035, '기쁨'),
#  (0.650702178478241, '싶'),
#  (0.6455563902854919, '나눠요'),
#  (0.6455432772636414, '미래'),
#  (0.6394328474998474, '꿈꾸'),
#  (0.635002613067627, '원한다')]

# %%
model.get_nearest_neighbors("부모")
# Out:
# [(0.8538607358932495, '조부모'),
#  (0.8321162462234497, '편부모'),
#  (0.8161343336105347, '친부모'),
#  (0.8103469014167786, '외조부모'),
#  (0.7993369698524475, '계부모'),
#  (0.7691270709037781, '증조부모'),
#  (0.7685805559158325, '생부모'),
#  (0.7620929479598999, '가족'),
#  (0.7488003969192505, '자녀'),
#  (0.7485790252685547, '양부모')]
